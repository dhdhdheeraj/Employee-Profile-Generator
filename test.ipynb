# %%
first_name = 'Dheeraj'

# %%
last_name = 'Gupta'

# %%
full_name = first_name + ' ' + last_name

# %%
print(full_name)
# Out:
# Dheeraj Gupta

# %%
address = 'Shahpuri Gate Mohalla, Sujanpur, Pathankot'

# %%
address += ', Punjab'

# %%
print(address)
# Out:
# Shahpuri Gate Mohalla, Sujanpur, Pathankot, Punjab

# %%
employee_age = 22

# %%
employee_info = full_name + ' is ' + str(employee_age) + ' years old.'

# %%
print(employee_info)
# Out:
# Dheeraj Gupta is 22 years old.

# %%
experience_years = 2

# %%
experience_info = 'Experience: ' + str(experience_years) + ' years'

# %%
print(experience_info)
# Out:
# Experience: 2 years

# %%
position = "Data Analyst"

# %%
salary = 75000

# %%
employee_card = f'Employee :{full_name} | Age: {employee_age} | Position: {position} | Salary: ${salary}'

# %%
print(employee_card)
# Out:
# Employee :Dheeraj Gupta | Age: 22 | Position: Data Analyst | Salary: $75000

# %%
employee_code = "DEV-2026-JD-001"

# %%
department = employee_code[0:3]

# %%
print(department)
# Out:
# DEV

# %%
year_code = employee_code[4:8]

# %%
print(year_code)
# Out:
# 2026

# %%
initials = employee_code[9:11]

# %%
print(initials)
# Out:
# JD
